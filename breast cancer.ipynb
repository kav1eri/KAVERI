# %%
#importing python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("C:\\Users\\kavz1\\Downloads\\archive (7).zip")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
# Assuming df is your DataFrame
# For example, if df is the variable holding your DataFrame
# df = pd.read_csv('your_data.csv')

# Drop the 'Unnamed: 32' column
df = df.drop('Unnamed: 32', axis=1)

# Now, df does not have the 'Unnamed: 32' column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame
# If df is the variable holding your DataFrame
# df = pd.read_csv('your_data.csv')

# Create a LabelEncoder
label_encoder = LabelEncoder()

# Apply label encoding to the 'diagnosis' column
df['diagnosis'] = label_encoder.fit_transform(df['diagnosis'])

# The 'diagnosis' column is now converted to integer values (e.g., 0 for 'B', 1 for 'M')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    int32
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming your DataFrame is named df
# If not, replace df with your actual DataFrame variable

# Get the list of column names excluding 'id' and 'diagnosis'
columns_to_plot = df.columns[2:]

# Loop through each column and create a scatter plot
for column in columns_to_plot:
    # Set a smaller figure size for each plot
    plt.figure(figsize=(2, 2))
    
    plt.scatter(df.index, df[column], alpha=0.5)
    plt.xlabel('Index')
    plt.ylabel(column)
    plt.title(f'Scatter plot for {column}')
    plt.show()
    # Adjust layout
plt.tight_layout()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming your DataFrame is named df
# If not, replace df with your actual DataFrame variable

# Get the correlation matrix
correlation_matrix = df.iloc[:, 1:].corr()  # Exclude 'id' for correlation

# Set up the matplotlib figure
plt.figure(figsize=(8, 6))

# Create the heatmap
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True, fmt=".2f")

# Add a title
plt.title("Correlation Heatmap")

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Assuming your DataFrame is named df
# If not, replace df with your actual DataFrame variable

# Get the list of column names excluding 'id' and 'diagnosis'
columns_to_plot = df.columns[2:]

# Set up subplots
fig, axes = plt.subplots(nrows=len(columns_to_plot)//3 + 1, ncols=3, figsize=(15, 20))

# Flatten the axes for easy iteration
axes = axes.flatten()

# Loop through each column and create a normal distribution curve
for i, column in enumerate(columns_to_plot):
    ax = axes[i]
    sns.histplot(df[column], kde=True, ax=ax, color='skyblue', stat='density')
    
    # Generate points for normal distribution curve
    mean = df[column].mean()
    std_dev = df[column].std()
    x = np.linspace(mean - 3*std_dev, mean + 3*std_dev, 100)
    y = (1/(std_dev * np.sqrt(2 * np.pi))) * np.exp( - (x - mean)**2 / (2 * std_dev**2) )
    ax.plot(x, y, color='red')
    
    ax.set_title(f'Distribution of {column}')
    ax.set_xlabel('')
    ax.set_ylabel('')
    ax.grid(True, linestyle='--', alpha=0.7)

# Remove empty plots
for i in range(len(columns_to_plot), len(axes)):
    fig.delaxes(axes[i])

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %%
import pandas as pd

# Assuming your DataFrame is named df
# If not, replace df with your actual DataFrame variable
# Select the variables you're interested in
selected_variables = ['radius_mean', 'area_mean', 'perimeter_mean', 'texture_mean']

# Create a new DataFrame with only the selected variables
selected_df = df[selected_variables]

# Define a function to remove outliers using IQR
def remove_outliers_iqr(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    filtered_data = data[(data >= lower_bound) & (data <= upper_bound)]
    return filtered_data, Q1, Q3, IQR

# Apply the function to remove outliers for each selected variable
for variable in selected_variables:
    filtered_data, Q1, Q3, IQR = remove_outliers_iqr(selected_df[variable])
    selected_df[variable] = filtered_data

    # Print quartile values
    print(f'{variable}: Q1={Q1}, Q3={Q3}, IQR={IQR}')

# Replace the original columns in the main DataFrame with the cleaned ones
df[selected_variables] = selected_df[selected_variables]
# Out:
# radius_mean: Q1=11.7, Q3=15.78, IQR=4.08
# area_mean: Q1=420.3, Q3=782.7, IQR=362.40000000000003
# perimeter_mean: Q1=75.17, Q3=104.1, IQR=28.929999999999993
# texture_mean: Q1=16.17, Q3=21.8, IQR=5.629999999999999

# %%
Q1
# Out:
# 16.17

# %%
Q3
# Out:
# 21.8

# %%
IQR
# Out:
# 5.629999999999999

# %%
from sklearn.preprocessing import MinMaxScaler

# Assuming your DataFrame is named df
# If not, replace df with your actual DataFrame variable

# Select the variables you want to scale
selected_variables = ['texture_mean', 'radius_mean', 'area_mean', 'perimeter_mean']

# Create a new DataFrame with only the selected variables
X = df[selected_variables]

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit the scaler on the training data and transform both training and testing data
X_scaled = scaler.fit_transform(X)

# Convert the scaled data back to a DataFrame (if needed)
X_scaled_df = pd.DataFrame(X_scaled, columns=selected_variables)

# Now, X_scaled_df contains your scaled features

# %%
from sklearn.model_selection import train_test_split

# Assuming your DataFrame is named df
# If not, replace df with your actual DataFrame variable

# Select the variables you're interested in
selected_variables = ['texture_mean', 'radius_mean', 'area_mean', 'perimeter_mean']

# Create a new DataFrame with only the selected variables
X = df[selected_variables]

# Define the target variable
y = df['diagnosis']

# Split the data into training and testing sets (e.g., 70% training, 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Now you have X_train (features for training), X_test (features for testing),
# y_train (target for training), and y_test (target for testing)

# %%
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Assuming your DataFrame is named df
# If not, replace df with your actual DataFrame variable

# Select the variables you're interested in
selected_variables = ['texture_mean', 'radius_mean', 'area_mean', 'perimeter_mean']

# Create a new DataFrame with only the selected variables
X = df[selected_variables]

# Define the target variable
y = df['diagnosis']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the imputer
imputer = SimpleImputer(strategy='mean')

# Fit and transform the imputer on the training data
X_train_imputed = imputer.fit_transform(X_train)

# Transform the testing data using the trained imputer
X_test_imputed = imputer.transform(X_test)

# Initialize the Logistic Regression model
model = LogisticRegression(random_state=42)

# Train the model on the training data
model.fit(X_train_imputed, y_train)

# Make predictions on the testing data
y_pred = model.predict(X_test_imputed)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.93

# %%
from sklearn.model_selection import GridSearchCV

# Define hyperparameter grid for Logistic Regression
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100]}

# Initialize Logistic Regression model
model = LogisticRegression(random_state=42)

# Initialize GridSearchCV
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='accuracy')

# Fit GridSearchCV on imputed training data
grid_search.fit(X_train_imputed, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print(f'Best Hyperparameters: {best_params}')

# Make predictions on the testing data using the best model
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test_imputed)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy with Best Model: {accuracy:.2f}')
# Out:
# Best Hyperparameters: {'C': 10}
# Accuracy with Best Model: 0.94

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

y_prob = best_model.predict_proba(X_test_imputed)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import accuracy_score, classification_report

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

# Generate classification report
report = classification_report(y_test, y_pred)
print("Classification Report:")
print(report)
# Out:
# Accuracy: 92.98%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94       108
#            1       0.89      0.92      0.91        63
#
#     accuracy                           0.93       171
#    macro avg       0.92      0.93      0.93       171
# weighted avg       0.93      0.93      0.93       171
